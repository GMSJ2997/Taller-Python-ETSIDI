# %%
#librerias utilizadas
import geopandas as gpd
import pandas as pd
import geoplot as gplt
import geoplot.crs as gcrs
import contextily as ctx
from cartopy import crs as ccrs
import matplotlib.pyplot as plt
import folium
import plotly.express as px
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
#descarga de información sobre aeropuertos en el mundo
import airportsdata

airports = airportsdata.load()

# %%
#convierte lista en dataframe
dfairports= pd.DataFrame([key for key in airports.keys()], columns=['icao'])
dfairports['iata']=[value['iata'] for value in airports.values()]
dfairports['name']=[value['name'] for value in airports.values()]
dfairports['city']=[value['city'] for value in airports.values()]
dfairports['subd']=[value['subd'] for value in airports.values()]
dfairports['country']=[value['country'] for value in airports.values()]
dfairports['elevation']=[value['elevation'] for value in airports.values()]
dfairports['lat']=[value['lat'] for value in airports.values()]
dfairports['lon']=[value['lon'] for value in airports.values()]
dfairports['tz']=[value['tz'] for value in airports.values()]
dfairports['lid']=[value['lid'] for value in airports.values()]

dfairports
# Out:
#        icao iata                         name          city       subd  \
# 0      00AA              Aero B Ranch Airport         Leoti     Kansas
# 1      00AK                      Lowell Field  Anchor Point     Alaska
# 2      00AL                      Epps Airpark       Harvest    Alabama
# 3      00AR                    Arland Airport    Bennington     Kansas
# 4      00AS                    Fulton Airport          Alex   Oklahoma
# ...     ...  ...                          ...           ...        ...
# 28126  ZYXC  XEN           Xingcheng Air Base                 Liaoning
# 28127  ZYYJ  YNJ  Yanji Chaoyangchuan Airport         Yanji      Jilin
# 28128  ZYYY           Shenyang Dongta Airport      Shenyang   Liaoning
# 28129  _AYM  AYM     Yas Island Seaplane Base    Yas Island  Abu Dhabi
# 28130  _OUK  OUK        Out Skerries Airstrip      Shetland   Scotland
#
#       country  elevation        lat         lon                 tz   lid
# ...

# %%
#filtro de los aeropuertos requeridos
airports=['Chek Lap Kok International Airport','Memphis International Airport','Ted Stevens Anchorage International Airport',
          'Shanghai Pudong International Airport','Louisville Muhammad Ali International Airport','Incheon International Airport',
          'Taiwan Taoyuan International Airport','Miami International Airport','Los Angeles International Airport','Narita International Airport',
          'Hamad International Airport',"Chicago O'Hare International Airport",'Frankfurt am Main International Airport',
          'Charles de Gaulle International Airport','Guangzhou Baiyun International Airport','Singapore Changi International Airport',
          'Cincinnati/Northern Kentucky International Airport','Dubai International Airport','Leipzig Halle Airport',"Shenzhen Bao'an International Airport",
          'Amsterdam Airport Schiphol','John F Kennedy International Airport','Istanbul Airport','London Heathrow Airport',
          'Indianapolis International Airport','Suvarnabhumi Airport','Liege Airport','Beijing Capital International Airport',
          'Luxembourg-Findel International Airport','Cologne Bonn Airport','Indira Gandhi International Airport','Tokyo International Airport',
          'Hangzhou Xiaoshan International Airport','Dallas-Fort Worth International Airport','Kansai International Airport',
          'Ontario International Airport','Chhatrapati Shivaji International Airport','El Dorado International Airport','Newark Liberty International Airport',
          'Malpensa International Airport','Noi Bai International Airport','Kuala Lumpur International Airport','Hartsfield - Jackson Atlanta International Airport',
          'Xinzheng Airport','Brussels Airport','Soekarno-Hatta International Airport','Abu Dhabi International Airport',
          'Tan Son Nhat International Airport','Ninoy Aquino International Airport','Metro Oakland International Airport',
          'Madrid Barajas International Airport','Daniel K Inouye International Airport','Philadelphia International Airport',
          'Licenciado Benito Juarez International Airport','George Bush Intcntl/Houston Airport','Chengdu Shuangliu International Airport',
          'San Francisco International Airport','Chicago/Rockford International Airport','Al Maktoum International Airport','Seattle-Tacoma International Airport']
df=dfairports.loc[dfairports['name'].isin(airports)]
df
# Out:
#        icao iata                                               name  \
# 6506   EBBR  BRU                                   Brussels Airport
# 6529   EBLG  LGG                                      Liege Airport
# 6630   EDDF  FRA            Frankfurt am Main International Airport
# 6633   EDDK  CGN                               Cologne Bonn Airport
# 6637   EDDP  LEJ                              Leipzig Halle Airport
# 7214   EGLL  LHR                            London Heathrow Airport
# 7349   EHAM  AMS                         Amsterdam Airport Schiphol
# 7467   ELLX  LUX            Luxembourg-Findel International Airport
# 11738  KATL  ATL  Hartsfield - Jackson Atlanta International Air...
# 12131  KCVG  CVG  Cincinnati/Northern Kentucky International Air...
# 12239  KDFW  DFW            Dallas-Fort Worth International Airport
# 12456  KEWR  EWR               Newark Liberty International Airport
# 12944  KIAH  IAH                George Bush Intcntl/Houston Airport
# ...

# %%
#lista de toneladas que mueve cada aeropuerto
ton={'HKG':{'iata':'HKG','name':'Chek Lap Kok International Airport','carga':'4,199,196'},'MEM':{'iata':'MEM','name':'Memphis International Airport','carga':'4,042,679'},
    'ANC':{'iata':'ANC','name':'Ted Stevens Anchorage International Airport','carga':'3,461,603'},'PVG':{'iata':'PVG','name':'Shanghai Pudong International Airport','carga':'3,117,216'},
    'SDF':{'iata':'SDF','name':'Louisville Muhammad Ali International Airport','carga':'3,067,234'},'ICN':{'iata':'ICN','name':'Incheon International Airport','carga':'2,945,855'},
    'TPE':{'iata':'TPE','name':'Taiwan Taoyuan International Airport','carga':'2,538,768'},'MIA':{'iata':'MIA','name':'Miami International Airport','carga':'2,499,837'},
    'LAX':{'iata':'LAX','name':'Los Angeles International Airport','carga':'2,489,854'},'NRT':{'iata':'NRT','name':'Narita International Airport','carga':'2,399,298'},
    'DOH':{'iata':'DOH','name':'Hamad International Airport','carga':'2,321,920'},'ORD':{'iata':'ORD','name':"Chicago O'Hare International Airport",'carga':'2,235,709'},
    'FRA':{'iata':'FRA','name':'Frankfurt am Main International Airport','carga':'1,967,450'},'CDG':{'iata':'CDG','name':'Charles de Gaulle International Airport','carga':'1,925,571'},
    'CAN':{'iata':'CAN','name':'Guangzhou Baiyun International Airport','carga':'1,884,784'},'SIN':{'iata':'SIN','name':'Singapore Changi International Airport','carga':'1,869,600'},
    'CVG':{'iata':'CVG','name':'Cincinnati/Northern Kentucky International Airport','carga':'1,794,451'},'DXB':{'iata':'DXB','name':'Dubai International Airport','carga':'1,727,815'},
    'LEJ':{'iata':'LEJ','name':'Leipzig Halle Airport','carga':'1,509,098'},'SZX':{'iata':'SZX','name':"Shenzhen Bao'an International Airport",'carga':'1,506,959'},
    'AMS':{'iata':'AMS','name':'Amsterdam Airport Schiphol','carga':'1,445,516'},'JFK':{'iata':'JFK','name':'John F Kennedy International Airport','carga':'1,441,905'},
    'IST':{'iata':'IST','name':'Istanbul Airport','carga':'1,439,997'},'LHR':{'iata':'LHR','name':'London Heathrow Airport','carga':'1,398,435'},
    'IND':{'iata':'IND','name':'Indianapolis International Airport','carga':'1,251,533'},'BKK':{'iata':'BKK','name':'Suvarnabhumi Airport','carga':'1,184,157'},
    'LGG':{'iata':'LGG','name':'Liege Airport','carga':'1,140,060'},'PEK':{'iata':'PEK','name':'Beijing Capital International Airport','carga':'988,868'},
    'LUX':{'iata':'LUX','name':'Luxembourg-Findel International Airport','carga':'970,118'},'CGN':{'iata':'CGN','name':'Cologne Bonn Airport','carga':'958,236'},
    'DEL':{'iata':'DEL','name':'Indira Gandhi International Airport','carga':'920,740'},'HND':{'iata':'HND','name':'Tokyo International Airport','carga':'857,233'},
    'HGH':{'iata':'HGH','name':'Hangzhou Xiaoshan International Airport','carga':'829,833'},'DFW':{'iata':'DFW','name':'Dallas-Fort Worth International Airport','carga':'818,933'},
    'KIX':{'iata':'KIX','name':'Kansai International Airport','carga':'815,961'},'ONT':{'iata':'ONT','name':'Ontario International Airport','carga':'779,441'},
    'BOM':{'iata':'BOM','name':'Chhatrapati Shivaji International Airport','carga':'775,085'},'BOG':{'iata':'BOG','name':'El Dorado International Airport','carga':'771,884'},
    'EWR':{'iata':'EWR','name':'Newark Liberty International Airport','carga':'732,336'},'MXP':{'iata':'MXP','name':'Malpensa International Airport','carga':'721,254'},
    'HAN':{'iata':'HAN','name':'Noi Bai International Airport','carga':'716,357'},'KUL':{'iata':'KUL','name':'Kuala Lumpur International Airport','carga':'693,514'},
    'ATL':{'iata':'ATL','name':'Hartsfield - Jackson Atlanta International Airport','carga':'688,614'},'CGO':{'iata':'CGO','name':'Xinzheng Airport','carga':'624,619'},
    'BRU':{'iata':'BRU','name':'Brussels Airport','carga':'621,482'},'CGK':{'iata':'CGK','name':'Soekarno-Hatta International Airport','carga':'609,517'},
    'AUH':{'iata':'AUH','name':'Abu Dhabi International Airport','carga':'605,367'},'SGN':{'iata':'SGN','name':'Tan Son Nhat International Airport','carga':'593,774'},
    'MNL':{'iata':'MNL','name':'Ninoy Aquino International Airport','carga':'583,309'},'OAK':{'iata':'OAK','name':'Metro Oakland International Airport','carga':'580,364'},
    'MAD':{'iata':'MAD','name':'Madrid Barajas International Airport','carga':'577,814'},'HNL':{'iata':'HNL','name':'Daniel K Inouye International Airport','carga':'568,778'},
    'PHL':{'iata':'PHL','name':'Philadelphia International Airport','carga':'567,232'},'MEX':{'iata':'MEX','name':'Licenciado Benito Juarez International Airport','carga':'548,743'},
    'IAH':{'iata':'IAH','name':'George Bush Intcntl/Houston Airport','carga':'542,072'},'CTU':{'iata':'CTU','name':'Chengdu Shuangliu International Airport','carga':'529,873'},
    'SFO':{'iata':'SFO','name':'San Francisco International Airport','carga':'502,978'},'RFD':{'iata':'RFD','name':'Chicago/Rockford International Airport','carga':'488,926'},
    'DWC':{'iata':'DWC','name':'Al Maktoum International Airport','carga':'467,907'},'SEA':{'iata':'SEA','name':'Seattle-Tacoma International Airport','carga':'456,289'}}
ton
# Out:
# {'HKG': {'iata': 'HKG',
#   'name': 'Chek Lap Kok International Airport',
#   'carga': '4,199,196'},
#  'MEM': {'iata': 'MEM',
#   'name': 'Memphis International Airport',
#   'carga': '4,042,679'},
#  'ANC': {'iata': 'ANC',
#   'name': 'Ted Stevens Anchorage International Airport',
#   'carga': '3,461,603'},
#  'PVG': {'iata': 'PVG',
#   'name': 'Shanghai Pudong International Airport',
#   'carga': '3,117,216'},
#  'SDF': {'iata': 'SDF',
#   'name': 'Louisville Muhammad Ali International Airport',
#   'carga': '3,067,234'},
#  'ICN': {'iata': 'ICN',
#   'name': 'Incheon International Airport',
#   'carga': '2,945,855'},
#  'TPE': {'iata': 'TPE',
#   'name': 'Taiwan Taoyuan International Airport',
#   'carga': '2,538,768'},
#  'MIA': {'iata': 'MIA',
#   'name': 'Miami International Airport',
#   'carga': '2,499,837'},
#  'LAX': {'iata': 'LAX',
#   'name': 'Los Angeles International Airport',
#   'carga': '2,489,854'},
#  'NRT': {'iata': 'NRT',
# ...

# %%
#dataframe con toneladas de carga movidas por aeropuerto
dfton= pd.DataFrame([key for key in ton.keys()], columns=['iata'])
dfton['name']=[value['name'] for value in ton.values()]
dfton['carga']=[value['carga'] for value in ton.values()]
dfton['carga']=dfton['carga'].str.replace(',','').astype('int')


dfton
# Out:
#    iata                                               name    carga
# 0   HKG                 Chek Lap Kok International Airport  4199196
# 1   MEM                      Memphis International Airport  4042679
# 2   ANC        Ted Stevens Anchorage International Airport  3461603
# 3   PVG              Shanghai Pudong International Airport  3117216
# 4   SDF      Louisville Muhammad Ali International Airport  3067234
# 5   ICN                      Incheon International Airport  2945855
# 6   TPE               Taiwan Taoyuan International Airport  2538768
# 7   MIA                        Miami International Airport  2499837
# 8   LAX                  Los Angeles International Airport  2489854
# 9   NRT                       Narita International Airport  2399298
# 10  DOH                        Hamad International Airport  2321920
# 11  ORD               Chicago O'Hare International Airport  2235709
# 12  FRA            Frankfurt am Main International Airport  1967450
# ...

# %%
#combinación de ambas df, inner join
df_combined=pd.merge(df,dfton,on=['iata','name'],how='inner')
df_combined.drop_duplicates()
df_combined
# Out:
#     icao iata                                               name  \
# 0   EBBR  BRU                                   Brussels Airport
# 1   EBLG  LGG                                      Liege Airport
# 2   EDDF  FRA            Frankfurt am Main International Airport
# 3   EDDK  CGN                               Cologne Bonn Airport
# 4   EDDP  LEJ                              Leipzig Halle Airport
# 5   EGLL  LHR                            London Heathrow Airport
# 6   EHAM  AMS                         Amsterdam Airport Schiphol
# 7   ELLX  LUX            Luxembourg-Findel International Airport
# 8   KATL  ATL  Hartsfield - Jackson Atlanta International Air...
# 9   KCVG  CVG  Cincinnati/Northern Kentucky International Air...
# 10  KDFW  DFW            Dallas-Fort Worth International Airport
# 11  KEWR  EWR               Newark Liberty International Airport
# 12  KIAH  IAH                George Bush Intcntl/Houston Airport
# ...

# %%
#Graficación 
fig = px.scatter_geo(df_combined,lat='lat',lon='lon',hover_name="name", hover_data=["city", "carga"],size= "carga",color='carga',title='Top 60 de aeropuertos por toneladas de mercancia')
fig.show()
# Out:
# <div>                            <div id="b9882bc4-76dd-4548-af2e-a8d86e25f666" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9882bc4-76dd-4548-af2e-a8d86e25f666")) {                    Plotly.newPlot(                        "b9882bc4-76dd-4548-af2e-a8d86e25f666",                        [{"customdata":[["Brussels",621482],["Liege",1140060],["Frankfurt am Main",1967450],["Cologne",958236],["Leipzig",1509098],["London",1398435],["Amsterdam",1445516],["Luxembourg",970118],["Atlanta",688614],["Covington",1794451],["Dallas-Fort Worth",818933],["Newark",732336],["Houston",542072],["Indianapolis",1251533],["New York",1441905],["Los Angeles",2489854],["Memphis",4042679],["Miami",2499837],["Oakland",580364],["Ontario",779441],["Chicago",2235709],["Philade
# ...
